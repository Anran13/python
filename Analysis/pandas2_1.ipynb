# %%
import pandas as pd

# %%
df = pd.read_csv('taiwan.csv')
# display(df)
df.head(3)
# Out:
#    國家      ID iso_code  洲名          日期  總確診數  新增確診數  七天移動平均新增確診數  總死亡數  新增死亡數  \
# 0  台灣  163987      TWN  亞洲  2020-01-16     0      0          0.0     0      0
# 1  台灣  163988      TWN  亞洲  2020-01-17     0      0          0.0     0      0
# 2  台灣  163989      TWN  亞洲  2020-01-18     0      0          0.0     0      0
#
#    ...  七天移動平均疫苗新增接種劑數  每百人接種疫苗劑數  每百人接種疫苗人數  疫情控管指數      總人口數  中位數年紀  \
# 0  ...             0.0        0.0        0.0    8.33  23855008   42.2
# 1  ...             0.0        0.0        0.0    8.33  23855008   42.2
# 2  ...             0.0        0.0        0.0    8.33  23855008   42.2
#
#    70歲以上人口比例   平均壽命  解除隔離數     解封指數
# 0      8.353  80.46      0  99999.0
# 1      8.353  80.46      0  99999.0
# 2      8.353  80.46      0  99999.0
#
# [3 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903 entries, 0 to 902
# Data columns (total 33 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   國家              903 non-null    object
#  1   ID              903 non-null    int64
#  2   iso_code        903 non-null    object
#  3   洲名              903 non-null    object
#  4   日期              903 non-null    object
#  5   總確診數            903 non-null    int64
#  6   新增確診數           903 non-null    int64
#  7   七天移動平均新增確診數     903 non-null    float64
#  8   總死亡數            903 non-null    int64
#  9   新增死亡數           903 non-null    int64
#  10  七天移動平均新增死亡數     903 non-null    float64
#  11  每百萬人確診數         903 non-null    float64
#  12  每百萬人死亡數         903 non-null    float64
#  13  傳染率             903 non-null    float64
#  14  新增檢驗件數          903 non-null    int64
#  15  總檢驗件數           903 non-null    int64
#  16  每千人檢驗件數         903 non-null    float64
# ...

# %%
# df.iloc[row,column] # index
# df.loc[row,column] # name
print(df.iloc[:5, [0,4,6]])

print(df.loc[:5,["國家", "日期", "總確診數"]])
# Out:
#    國家          日期  新增確診數
# 0  台灣  2020-01-16      0
# 1  台灣  2020-01-17      0
# 2  台灣  2020-01-18      0
# 3  台灣  2020-01-19      0
# 4  台灣  2020-01-20      0
#    國家          日期  總確診數
# 0  台灣  2020-01-16     0
# 1  台灣  2020-01-17     0
# 2  台灣  2020-01-18     0
# 3  台灣  2020-01-19     0
# 4  台灣  2020-01-20     0
# 5  台灣  2020-01-21     0

# %%
print(df.iloc[:3])

df1 = df[df['新增確診數'] >= 12]
print(df.iloc[:3])
# Out:
#    國家      ID iso_code  洲名          日期  總確診數  新增確診數  七天移動平均新增確診數  總死亡數  新增死亡數  \
# 0  台灣  163987      TWN  亞洲  2020-01-16     0      0          0.0     0      0
# 1  台灣  163988      TWN  亞洲  2020-01-17     0      0          0.0     0      0
# 2  台灣  163989      TWN  亞洲  2020-01-18     0      0          0.0     0      0
#
#    ...  七天移動平均疫苗新增接種劑數  每百人接種疫苗劑數  每百人接種疫苗人數  疫情控管指數      總人口數  中位數年紀  \
# 0  ...             0.0        0.0        0.0    8.33  23855008   42.2
# 1  ...             0.0        0.0        0.0    8.33  23855008   42.2
# 2  ...             0.0        0.0        0.0    8.33  23855008   42.2
#
#    70歲以上人口比例   平均壽命  解除隔離數     解封指數
# 0      8.353  80.46      0  99999.0
# 1      8.353  80.46      0  99999.0
# 2      8.353  80.46      0  99999.0
#
# [3 rows x 33 columns]
#    國家      ID iso_code  洲名          日期  總確診數  新增確診數  七天移動平均新增確診數  總死亡數  新增死亡數  \
# 0  台灣  163987      TWN  亞洲  2020-01-16     0      0          0.0     0      0
# ...

# %%
# only ascii charater can compare 
print(df['日期'] <= "2020-01-20")

condition = (df['日期'] > "2020-01-20") & (df['日期'] <= "2020-01-31")
df2 = df[condition]
print(df2.iloc[:3,])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 898    False
# 899    False
# 900    False
# 901    False
# 902    False
# Name: 日期, Length: 903, dtype: bool
#    國家      ID iso_code  洲名          日期  總確診數  新增確診數  七天移動平均新增確診數  總死亡數  新增死亡數  \
# 5  台灣  163992      TWN  亞洲  2020-01-21     0      0          0.0     0      0
# 6  台灣  163993      TWN  亞洲  2020-01-22     1      0          0.0     0      0
# 7  台灣  163994      TWN  亞洲  2020-01-23     1      0          0.0     0      0
#
#    ...  七天移動平均疫苗新增接種劑數  每百人接種疫苗劑數  每百人接種疫苗人數  疫情控管指數      總人口數  中位數年紀  \
# 5  ...             0.0        0.0        0.0   13.89  23855008   42.2
# 6  ...             0.0        0.0        0.0   13.89  23855008   42.2
# 7  ...             0.0        0.0        0.0   19.44  23855008   42.2
#
#    70歲以上人口比例   平均壽命  解除隔離數     解封指數
# 5      8.353  80.46      0  99999.0
# 6      8.353  80.46      0  99999.0
# 7      8.353  80.46      0  99999.0
#
# [3 rows x 33 columns]

# %%
# another way
df.query('日期 >= "2020-01-20" and 日期 < "2020-02-01" and 新增確診數 >= 3')
# Out:
#     國家      ID iso_code  洲名          日期  總確診數  新增確診數  七天移動平均新增確診數  總死亡數  \
# 12  台灣  163999      TWN  亞洲  2020-01-28     8      3          1.0     0
#
#     新增死亡數  ...  七天移動平均疫苗新增接種劑數  每百人接種疫苗劑數  每百人接種疫苗人數  疫情控管指數      總人口數  中位數年紀  \
# 12      0  ...             0.0        0.0        0.0   19.44  23855008   42.2
#
#     70歲以上人口比例   平均壽命  解除隔離數     解封指數
# 12      8.353  80.46      0  99999.0
#
# [1 rows x 33 columns]

# %%
pd.to_datetime(df['日期']).dtype

df['date'] = pd.to_datetime(df['日期'])
df.info()

print(df.query('date in "2020/01/16"'))
print(df.query('date == "2020/01/16"'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 903 entries, 0 to 902
# Data columns (total 34 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   國家              903 non-null    object
#  1   ID              903 non-null    int64
#  2   iso_code        903 non-null    object
#  3   洲名              903 non-null    object
#  4   日期              903 non-null    object
#  5   總確診數            903 non-null    int64
#  6   新增確診數           903 non-null    int64
#  7   七天移動平均新增確診數     903 non-null    float64
#  8   總死亡數            903 non-null    int64
#  9   新增死亡數           903 non-null    int64
#  10  七天移動平均新增死亡數     903 non-null    float64
#  11  每百萬人確診數         903 non-null    float64
#  12  每百萬人死亡數         903 non-null    float64
#  13  傳染率             903 non-null    float64
#  14  新增檢驗件數          903 non-null    int64
#  15  總檢驗件數           903 non-null    int64
#  16  每千人檢驗件數         903 non-null    float64
# ...

# %%
df3 = df.set_index('date')
df3.head(3)
# Out:
#             國家      ID iso_code  洲名          日期  總確診數  新增確診數  七天移動平均新增確診數  \
# date
# 2020-01-16  台灣  163987      TWN  亞洲  2020-01-16     0      0          0.0
# 2020-01-17  台灣  163988      TWN  亞洲  2020-01-17     0      0          0.0
# 2020-01-18  台灣  163989      TWN  亞洲  2020-01-18     0      0          0.0
#
#             總死亡數  新增死亡數  ...  七天移動平均疫苗新增接種劑數  每百人接種疫苗劑數  每百人接種疫苗人數  疫情控管指數  \
# date                     ...
# 2020-01-16     0      0  ...             0.0        0.0        0.0    8.33
# 2020-01-17     0      0  ...             0.0        0.0        0.0    8.33
# 2020-01-18     0      0  ...             0.0        0.0        0.0    8.33
#
#                 總人口數  中位數年紀  70歲以上人口比例   平均壽命  解除隔離數     解封指數
# date
# 2020-01-16  23855008   42.2      8.353  80.46      0  99999.0
# 2020-01-17  23855008   42.2      8.353  80.46      0  99999.0
# 2020-01-18  23855008   42.2      8.353  80.46      0  99999.0
#
# [3 rows x 33 columns]

# %%
print(df3.loc['2020-02'])
print(df3.loc['2020-01':'2020-02'])
# Out:
#             國家      ID iso_code  洲名          日期  總確診數  新增確診數  七天移動平均新增確診數  \
# date
# 2020-02-01  台灣  164003      TWN  亞洲  2020-02-01    10      0        1.000
# 2020-02-02  台灣  164004      TWN  亞洲  2020-02-02    10      0        0.857
# 2020-02-03  台灣  164005      TWN  亞洲  2020-02-03    10      0        0.714
# 2020-02-04  台灣  164006      TWN  亞洲  2020-02-04    11      1        0.429
# 2020-02-05  台灣  164007      TWN  亞洲  2020-02-05    11      0        0.429
# 2020-02-06  台灣  164008      TWN  亞洲  2020-02-06    16      5        1.000
# 2020-02-07  台灣  164009      TWN  亞洲  2020-02-07    16      0        0.857
# 2020-02-08  台灣  164010      TWN  亞洲  2020-02-08    17      1        1.000
# 2020-02-09  台灣  164011      TWN  亞洲  2020-02-09    18      1        1.143
# 2020-02-10  台灣  164012      TWN  亞洲  2020-02-10    18      0        1.143
# 2020-02-11  台灣  164013      TWN  亞洲  2020-02-11    18      0        1.000
# 2020-02-12  台灣  164014      TWN  亞洲  2020-02-12    18      0        1.000
# ...
