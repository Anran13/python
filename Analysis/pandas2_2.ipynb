# %%
# if installed successfully, type "pip show yfinance" in terminal
import yfinance as yf

# %%
start_date = '2024-01-01'
end_date = '2024-06-01'
tw2330 = yf.download('2330.TW', start=start_date, end=end_date,auto_adjust=True)
tw2330.head(3)
tw2330.info()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 98 entries, 2024-01-02 to 2024-05-31
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Close, 2330.TW)   98 non-null     float64
#  1   (High, 2330.TW)    98 non-null     float64
#  2   (Low, 2330.TW)     98 non-null     float64
#  3   (Open, 2330.TW)    98 non-null     float64
#  4   (Volume, 2330.TW)  98 non-null     int64
# dtypes: float64(4), int64(1)
# memory usage: 4.6 KB

# %%
print(tw2330['Close']['2330.TW'])
print(tw2330['Close','2330.TW'])
# Out:
# Date
# 2024-01-02    577.962952
# 2024-01-03    563.343262
# 2024-01-04    565.292419
# 2024-01-05    561.393860
# 2024-01-08    568.216431
#                  ...
# 2024-05-27    850.919067
# 2024-05-28    847.002258
# 2024-05-29    839.168701
# 2024-05-30    820.563965
# 2024-05-31    803.917664
# Name: 2330.TW, Length: 98, dtype: float64
# Date
# 2024-01-02    577.962952
# 2024-01-03    563.343262
# 2024-01-04    565.292419
# 2024-01-05    561.393860
# 2024-01-08    568.216431
#                  ...
# 2024-05-27    850.919067
# 2024-05-28    847.002258
# 2024-05-29    839.168701
# 2024-05-30    820.563965
# 2024-05-31    803.917664
# Name: (Close, 2330.TW), Length: 98, dtype: float64

# %%
tw2303 = yf.download('2303.TW', start=start_date, end=end_date,auto_adjust=True)
tw2454 = yf.download('2454.TW', start=start_date, end=end_date,auto_adjust=True)  
tw2317 = yf.download('2317.TW', start=start_date, end=end_date,auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
import pandas as pd

# %%
tw2330_data= tw2330[('Close','2330.TW')]
tw2303_data = tw2303[('Close','2303.TW')]
tw2454_data = tw2454[('Close','2454.TW')]
tw2317_data = tw2317[('Close','2317.TW')]

# %%
data = {
    "tsmc":tw2330_data,
    "umc":tw2303_data,
    "mediatec":tw2454_data,
    "honhai":tw2317_data
}

df = pd.DataFrame(data)
df.head(3)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 98 entries, 2024-01-02 to 2024-05-31
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tsmc      98 non-null     float64
#  1   umc       98 non-null     float64
#  2   mediatec  98 non-null     float64
#  3   honhai    98 non-null     float64
# dtypes: float64(4)
# memory usage: 3.8 KB

# %%
import os
from datetime import datetime
import pandas as pd

today = datetime.now().strftime('%Y-%m-%d')
stock_id = 2303

filepath=os.path.join('data/', f'{stock_id}_{today}.csv')
# print(filepath)
# print(os.path.exists(filepath))

# test_df = pd.read_csv(filepath)
# print(test_df)

test_df = pd.read_csv(filepath, skiprows=2)
test_df.columns = ['Date','Close','High','Low','Open','Volume']
print(test_df)
print(test_df.info())
# Out:
#             Date      Close       High        Low       Open     Volume
# 0     2000-01-04  18.782606  18.941108  18.227845  18.544852  332630460
# 1     2000-01-05  18.703356  18.782606  18.227845  18.386348  292754299
# 2     2000-01-06  18.307095  18.703352  18.227841  18.703352  248928848
# 3     2000-01-07  17.752338  17.990092  17.276829  17.831589  269228882
# 4     2000-01-10  18.227840  18.386344  16.959819  16.959819  380487972
# ...          ...        ...        ...        ...        ...        ...
# 6361  2025-07-25  43.500000  43.750000  43.299999  43.400002   17661776
# 6362  2025-07-28  43.500000  43.599998  43.000000  43.500000   35776877
# 6363  2025-07-29  42.799999  43.349998  42.799999  43.299999   35741812
# 6364  2025-07-30  42.549999  42.900002  42.099998  42.799999   45900200
# 6365  2025-07-31  41.549999  42.250000  41.549999  42.250000   42952609
#
# [6366 rows x 6 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6366 entries, 0 to 6365
# ...

# %%
today = datetime.now().strftime('%Y-%m-%d')
    
# Define a dictionary to map stock IDs to desired column names
stock_names = {
    '2330': 'tsmc',
    '2303': 'umc',
    '2454': 'mediatec',
    '2317': 'honhai'
    }

combined_df = pd.DataFrame()

for stock_id, col_name in stock_names.items():
    filepath = os.path.join('data/', f'{stock_id}_{today}.csv')
    if os.path.exists(filepath):
        df = pd.read_csv(filepath, skiprows=2)
        df.columns = ['Date','Close','High','Low','Open','Volume']
        df.set_index('Date',inplace=True)
        # print(df.head(3))

        # Select only the 'Close' price and rename the column
        close_prices = df[['Close']].rename(columns={'Close': col_name})
         
        if combined_df.empty:
            combined_df = close_prices
            # print(combined_df.head(3))
        else:
            combined_df = combined_df.join(close_prices, how='outer')
            print(combined_df.head(3))
    else:
        print(f"Warning: Data file for {stock_id} ({filepath}) not found. Skipping.")

# Reset index to make 'Date' a column and rename it to 'date'
combined_df = combined_df.reset_index().rename(columns={'Date': 'date'})
print(combined_df.head(3))
# Out:
#                  tsmc        umc
# Date
# 2000-01-04  33.784512  18.782606
# 2000-01-05  34.543640  18.703356
# 2000-01-06  33.784512  18.307095
#                  tsmc        umc  mediatec
# Date
# 2000-01-04  33.784512  18.782606       NaN
# 2000-01-05  34.543640  18.703356       NaN
# 2000-01-06  33.784512  18.307095       NaN
#                  tsmc        umc  mediatec     honhai
# Date
# 2000-01-03        NaN        NaN       NaN  21.776379
# 2000-01-04  33.784512  18.782606       NaN  11.539950
# 2000-01-05  34.543640  18.703356       NaN  11.539950
#          date       tsmc        umc  mediatec     honhai
# 0  2000-01-03        NaN        NaN       NaN  21.776379
# 1  2000-01-04  33.784512  18.782606       NaN  11.539950
# 2  2000-01-05  34.543640  18.703356       NaN  11.539950
